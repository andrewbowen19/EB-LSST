# %% [markdown]
# Reading in .csv files from output, gonna plot a whole lotta stuff

# %%
# Importing needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.coordinates import SkyCoord, Distance

# %%
# # Reading in first 2 lines of data file, can be arbitrary data file from Aaron's directory on Quest
# filename = '3174output_file.csv'
# dat1 = pd.read_csv(filename, sep = ',', header=0, nrows = 1) 
# # print(dat1)
# RA = dat1['OpSimRA']
# Dec = dat1['OpSimDec']
# print(RA)

# %%
# Skipping first 2 lines to read in rest of data file
dat2 = pd.read_csv(filename, sep = ',', header=2)
# print(dat2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-37804c19bde0> in <module>()
#       1 # Skipping first 2 lines to read in rest of data file
# ----> 2 dat2 = pd.read_csv(filename, sep = ',', header=2)
#       3 # print(dat2)
#
# ...

# %%
PeriodIn = dat2['p'] # input period -- 'p' in data file
PeriodOut = dat2['LSM_PERIOD'] #LSM_PERIOD in data file
Mass1 = dat2['m1']
Mass2 = dat2['m2']
radius1 = dat2['r1']
radius2 = dat2['r2']

P_err1 = PeriodIn - (PeriodIn * 0.1)
P_err2 = PeriodIn + (PeriodIn * 0.1)
Period_Match = np.array([])

# if P_err1 <= PeriodOut <= P_err2:
#     Period_Match = np.append(Period_Match, PeriodOut)


# print(type(PeriodIn))
print(Period_Match)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-176e1880602e> in <module>()
# ----> 1 PeriodIn = dat2['p'] # input period -- 'p' in data file
#       2 PeriodOut = dat2['LSM_PERIOD'] #LSM_PERIOD in data file
#       3 Mass1 = dat2['m1']
#       4 Mass2 = dat2['m2']
#       5 radius1 = dat2['r1']
#
# NameError: name 'dat2' is not defined

# %%
# Plotting period distribution
f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.hist(np.log10(PeriodIn), bins = 100, range = (0,10))
ax2.hist(np.log10(PeriodOut), bins = 100, range = (0,10))
ax1.set_xlabel('Log(Period) Input', fontsize = 16)
ax2.set_xlabel('Log(Period) LSM', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7be243a3da0d> in <module>()
#       1 # Plotting period distribution
#       2 f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
# ----> 3 ax1.hist(np.log10(PeriodIn), bins = 100, range = (0,10))
#       4 ax2.hist(np.log10(PeriodOut), bins = 100, range = (0,10))
#       5 ax1.set_xlabel('Log(Period) Input', fontsize = 16)
#
# NameError: name 'PeriodIn' is not defined

# %%
# Plotting masses
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)

f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)

ax1.hist(Mass1, bins = 100, range = (0,10), color = '#99badd')
ax2.hist(Mass2, bins = 100, range = (0,10), color = '#cc5500')
ax1.set_xlabel('$M_1$ ($M_\odot$)', fontsize = 16)
ax2.set_xlabel('$M_2$ ($M_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)

# %%
# Plotting Radii
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(radius1, bins = 100, range = (0,10), color = '#99badd')
ax2.hist(radius2, bins = 100, range = (0,10), color = '#cc5500')
ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
ax2.set_xlabel('$R_2$ ($R_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2f9e9fa01e8d> in <module>()
#       3 f.subplots_adjust(wspace=0)
#       4 plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
# ----> 5 ax1.hist(radius1, bins = 100, range = (0,10), color = '#99badd')
#       6 ax2.hist(radius2, bins = 100, range = (0,10), color = '#cc5500')
#       7 ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
#
# NameError: name 'radius1' is not defined

# %%
# Plo
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(radius1, bins = 100, range = (0,10), color = 'Grey')
ax2.hist(radius2, bins = 100, range = (0,10), color = '#4E2A84')
ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
ax2.set_xlabel('$R_2$ ($R_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e984cbb82892> in <module>()
#       3 f.subplots_adjust(wspace=0)
#       4 plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
# ----> 5 ax1.hist(radius1, bins = 100, range = (0,10), color = 'Grey')
#       6 ax2.hist(radius2, bins = 100, range = (0,10), color = '#4E2A84')
#       7 ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
#
# NameError: name 'radius1' is not defined

# %%
filename = '3641output_file.csv'
dat1 = pd.read_csv(filename, sep = ',', header=0, nrows = 1)
dat2 = pd.read_csv(filename, sep = ',', header=2)

# %%
PeriodIn = dat2['p'] # input period -- 'p' in data file
PeriodOut = dat2['LSM_PERIOD'] #LSM_PERIOD in data file
Mass1 = dat2['m1']
Mass2 = dat2['m2']
radius1 = dat2['r1']
radius2 = dat2['r2']

# Period_Match = dat2[PeriodIn == (PeriodOut+0.1*PeriodIn)]
# print(Period_Match)

# %%
# Plotting log(period)
f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.hist(np.log10(PeriodIn), bins = 100, range = (0,10), color = '#99badd')
ax2.hist(np.log10(PeriodOut), bins = 100, range = (0,10), color = '#99badd')
ax1.set_xlabel('Log(Period) Input', fontsize = 16)
ax2.set_xlabel('Log(Period) LSM', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('One_file_Log.png')

# Plotting period
f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.hist(PeriodIn, bins = 100, range = (0,10), color = '#99badd')
ax2.hist(PeriodOut, bins = 100, range = (0,10), color = '#99badd')
ax1.set_xlabel('Input Period (Days)', fontsize = 16)
ax2.set_xlabel('Output Period (Days)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('One_file_P.pdf')
f.savefig('One_file_P.png')
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Plotting Mass
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(Mass1, bins = 100, range = (0,10), color = '#99badd')
ax2.hist(Mass2, bins = 100, range = (0,10), color = '#cc5500')
ax1.set_xlabel('$M_1$ ($M_\odot$)', fontsize = 16)
ax2.set_xlabel('$M_2$ ($M_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)

# Plotting raddi
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(radius1, bins = 100, range = (0,10), color = '#99badd')
ax2.hist(radius2, bins = 100, range = (0,10), color = '#cc5500')
ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
ax2.set_xlabel('$R_2$ ($R_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# Out:
# Text(0,0.5,'Number of Binaries, N')

# %%
OpSimCoords = SkyCoord(dat1['OpSimRA'],dat1['OpSimDec'],unit=(u.degree, u.degree),frame='icrs')
print(OpSimCoords)
# f, ax = plt.subplots(subplot_kw={'projection': "mollweide"})

u_obs = dat1['NOpSimObs_u']
g_obs = dat1['NOpSimObs_g']
r_obs = dat1['NOpSimObs_r']
i_obs = dat1['NOpSimObs_i']
z_obs = dat1['NOpSimObs_z']
y_obs = dat1['NOpSimObs_y']


plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)
plt.scatter(dat1['OpSimRA'], dat1['OpSimDec'], cmap = 'cool')
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(75.34122467, 22.26730919)]>

# %%
# Trying to read in all files at once
import glob
path ='/Users/andrewbowen/BO_EB-LSST/code/OpSim' # use your path
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_1 = []
list_2 = []
for file_ in allFiles:
    dat1 = pd.read_csv(file_, sep = ',', header=0, nrows = 1)
    dat2 = pd.read_csv(file_, sep = ',', header=2)
    dat2['RA'] = dat1['OpSimRA'][0]
    dat2['Dec'] = dat1['OpSimDec'][0]
    list_1.append(dat1)
    list_2.append(dat2)
frame1 = pd.concat(list_1)#, ignore_index = True) #RA, Dec and id stuff
frame2 = pd.concat(list_2)#, ignore_index = True) #Actual data

# %%
#print(dat1['OpSimRA'][0])
frame2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-75ee16780002> in <module>()
#       1 #print(dat1['OpSimRA'][0])
# ----> 2 frame2
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
u_obs = frame1['NOpSimObs_u']
g_obs = frame1['NOpSimObs_g']
r_obs = frame1['NOpSimObs_r']
i_obs = frame1['NOpSimObs_i']
z_obs = frame1['NOpSimObs_z']
y_obs = frame1['NOpSimObs_y']

# %%
PeriodIn = frame2['p'] # input period -- 'p' in data file
PeriodOut = frame2['LSM_PERIOD'] #LSM_PERIOD in data file
Mass1 = frame2['m1']
Mass2 = frame2['m2']
radius1 = frame2['r1']
radius2 = frame2['r2']

# %%
# Plotting log(period)
f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.hist(np.log10(PeriodIn), bins = 100, range = (0,10), color = '#339933')
ax2.hist(np.log10(PeriodOut), bins = 100, range = (0,10), color = '#339933')
ax1.set_xlabel('Log(Period) Input', fontsize = 16)
ax2.set_xlabel('Log(Period) LSM', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('Log-Period_Comparison.pdf')

# Plotting period
f,(ax1,ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.hist(PeriodIn, bins = 100, range = (0,10), color = '#339933')
ax2.hist(PeriodOut, bins = 100, range = (0,10), color = '#339933')
ax1.set_xlabel('Input Period (Days)', fontsize = 16)
ax2.set_xlabel('Output Period (Days)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('Period_Comparison.pdf')
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.

# %%
# Plotting Mass -- All masses data
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(Mass1, bins = 100, range = (0,2), color = '#99badd')
ax2.hist(Mass2, bins = 100, range = (0,2), color = '#cc5500')
ax1.set_xlabel('$M_1$ ($M_\odot$)', fontsize = 16)
ax2.set_xlabel('$M_2$ ($M_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)

# Plotting raddi -- All radii data
f,(ax1,ax2) = plt.subplots(1,2, figsize = (10,7), sharey = True)
f.subplots_adjust(wspace=0)
plt.setp([a.get_yticklabels() for a in f.axes[:-1]], visible=True)
ax1.hist(radius1, bins = 100, range = (0,2), color = '#99badd')
ax2.hist(radius2, bins = 100, range = (0,2), color = '#cc5500')
ax1.set_xlim((0,2))
ax2.set_xlim((0,2))
ax1.set_xlabel('$R_1$ ($R_\odot$)', fontsize = 16)
ax2.set_xlabel('$R_2$ ($R_\odot$)', fontsize = 16)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# Out:
# Text(0,0.5,'Number of Binaries, N')

# %%
# Mollweide View of all observation coordinates

RA = frame1['OpSimRA']
Dec = frame1['OpSimDec']
OpSimCoords = SkyCoord(RA,Dec,unit=(u.degree, u.degree),frame='icrs')
# print(OpSimCoords)


plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)


plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian,cmap='cool')
plt.xlabel('RA', fontsize = 16)
plt.ylabel('$\delta$', fontsize = 16)

# plt.scatter(dat1['OpSimRA'], dat1['OpSimDec'], cmap = 'cool')
plt.title('All Filter Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'All Filter Coordinates')

# %%
# u filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)


plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian, s=5,\
            cmap = 'Blues', c = frame1['NOpSimObs_u'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)


plt.title('u Coordinates', fontsize = 16)
plt.savefig('u_mollweide.pdf')
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))

# %%
# g filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian,s = 5,\
            cmap = 'Blues', c = frame1['NOpSimObs_g'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)

plt.title('g Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'g Coordinates')

# %%
# r filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian, s=5,\
            cmap = 'Blues', c = frame1['NOpSimObs_r'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)

plt.title('r Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'r Coordinates')

# %%
# i filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian, s=5,\
            cmap = 'Blues', c = frame1['NOpSimObs_i'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)

plt.title('i Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'i Coordinates')

# %%
# z filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian,s = 5,\
            cmap = 'Blues', c = frame1['NOpSimObs_z'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)

plt.title('z Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'z Coordinates')

# %%
# y filter
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

plt.scatter(OpSimCoords.ra.wrap_at(180.*u.degree).radian,OpSimCoords.dec.radian, s = 5,\
            cmap = 'Blues', c = frame1['NOpSimObs_y'], vmin = 0, vmax = 200)
clb = plt.colorbar()
clb.set_label(r'Number of Observations', rotation = 270)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16)

plt.title('y Coordinates', fontsize = 16)
# Out:
# /Users/andrewbowen/anaconda3/lib/python3.6/site-packages/matplotlib/projections/geo.py:426: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))
# Text(0.5,1,'y Coordinates')

# %%
# Period Recovery 

Perr1 = PeriodIn - (0.1*PeriodIn)
Perr2 = PeriodIn + (0.1*PeriodIn)

# P_Recover = frame2.loc[(PeriodOut >= Perr1) & (PeriodOut <= Perr2)]

pdiff = abs(PeriodIn - PeriodOut)/PeriodIn
P_Recover = frame2.loc[pdiff < 0.1]

# print(P_Recover)
# print(P_Recover.shape[0])

# %%
# ID/All Binaries

# print(P_Recover.shape)
# print(frame2.shape)

Total_Recovered = P_Recover['p'].count
Total_Periods = frame2['p'].count
# print(Total_Recovered)
ID_rate = P_Recover.shape[0]/frame2.shape[0]
print(ID_rate)
# Period_Recovery_Rate = Total_Recovered/Total_Periods
# Out:
# 0.000844663070236315

# %%
Half_Period = 0.5* PeriodIn
LSM_Half_Period = 0.5 * PeriodIn

# HPerr1 = Half_Period - (0.1*Half_Period)
# HPerr2 = Half_Period + (0.1*Half_Period)
hpdiff = abs(Half_Period - LSM_Half_Period)/Half_Period
HP_Recover = frame2.loc[hpdiff < 0.1]
pdiff = abs(PeriodIn.values - PeriodOut.values)/PeriodIn.values
P_Recover = frame2.loc[(pdiff < 0.1) | (hpdiff < 0.1)]

full_id_rate = P_Recover.shape[0]/frame2.shape[0]
print('ID rate of All binaries with Half-Period:')
print(full_id_rate)
# print(PeriodIn, Half_Period)
# print(HP_Recover)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-785396b6c8f4> in <module>()
#       7 HP_Recover = frame2.loc[hpdiff < 0.1]
#       8 pdiff = abs(PeriodIn.values - PeriodOut.values)/PeriodIn.values
# ----> 9 P_Recover = frame2.loc[(pdiff < 0.1) | (hpdiff < 0.1)]
#      10
#      11 full_id_rate = P_Recover.shape[0]/frame2.shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1866             return self._get_slice_axis(key, axis=axis)
#    1867         elif com.is_bool_indexer(key):
# ...

# %%
PeriodIn2 = 2 * PeriodIn
PeriodOut2 = 2 * PeriodOut

dpdiff = hpdiff = abs(PeriodIn2 - PeriodOut2)/PeriodIn2
DP_Recover = frame2.loc[dpdiff <0.1]
P_Recover = frame2.loc[(pdiff < 0.1) | (hpdiff < 0.1) | (dpdiff<0.1)]
print(P_Recover.shape[0])

# %%
# Detected binaries/All Binaries

detected_bins = frame2.loc[PeriodOut != -999]
print(detected_bins.shape[0])
detection_rate = detected_bins.shape[0]/frame2.shape[0]
print(detection_rate)
# Out:
# 624196
# 0.014771392423983044

# %%
# ID/Detected

finder = P_Recover.shape[0]/detected_bins.shape[0]
print(finder)

# %%
RA_dec_pairs = []
for pair in list(zip(frame2['RA'], frame2['Dec'])):
    if pair in RA_dec_pairs:
        continue
    RA_dec_pairs.append(pair)

# %%
group_percents = np.array([])
for pair in RA_dec_pairs:
#     print(pair[0])
    indices = np.where(np.logical_and(frame2['RA'] == pair[0], frame2['Dec'] == pair[1]))
    total = len(indices)
    count = 0
    for i in indices:
#         print(i)
#         print(pdiff[i])
        for d in pdiff[i]:
            if d <= .1:
                count+= 1
    percent_rec = float(count)/float(total)
    group_percents = np.append(group_percents, percent_rec)
#     print(percent_rec)

# %%
# Need to assign percent_rec to each ra/dec
# group_percents = group_percents/100
print(max(group_percents))
print(min(group_percents))
# print(RA_dec_pairs)

all_ra = np.array([])
all_dec = np.array([])

# %%
for coord in RA_dec_pairs:
    all_ra = np.append(all_ra, coord[0])
    all_dec = np.append(all_dec, coord[1])
#     All_Coords = SkyCoord(coord[0],coord[1],unit=(u.degree, u.degree),frame='icrs')
(all_ra,all_dec)

# %%
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection="mollweide")#, axisbg ='LightCyan')
ax.grid(True)
ax.scatter(all_ra,all_dec)

# %%
# All/Detectable inclination plots
inc = frame2['i']
d_inc = detected_bins['i']
id_inc = P_Recover['i']


f,(ax1,ax2, ax3) = plt.subplots(1,3, figsize = (10,5))
ax1.hist(inc, bins = 100, range = (0,90), color = '#4E2A84')
ax2.hist(d_inc, bins = 100, range = (0,90), color = '#4E2A84')
ax3.hist(id_inc, bins = 100, range = (0,90), color = '#4E2A84')
ax1.set_xlabel('Inclination (All Binaries)', fontsize = 12)
ax2.set_xlabel('Inclination (Detected Binaries)', fontsize = 12)
ax3.set_xlabel('Inclination (Identified)', fontsize = 12)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
# f.savefig('inc_hist.pdf')

# %%
# Eccentricity plot
ecc = frame2['e']
d_ecc = detected_bins['e']
id_ecc = P_Recover['e']

f,(ax1,ax2,ax3) = plt.subplots(1,3, figsize = (10,6))
ax1.hist(ecc, bins = 50, range = (0,1), color = '#ff7733')
ax2.hist(d_ecc, bins = 50, range = (0,1), color = '#ff7733')
ax3.hist(id_ecc, bins = 50, range = (0,1), color = '#ff7733')
ax1.set_xlabel('Eccentricity (All Binaries)', fontsize = 12)
ax2.set_xlabel('Eccentricity (Detected Binaries)', fontsize = 12)
ax3.set_xlabel('Eccentricity (Identified Binaries)', fontsize = 12)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('ecc_hist.pdf')

# %%
# Plotting mass ratio (m2/m1)
mass1= frame2['m1']
mass2 = frame2['m2']
mass_ratio = mass2/mass1

i_mass1 = P_Recover['m1']
i_mass2 = P_Recover['m2']
i_mass_ratio = i_mass2/i_mass1
d_mass1 = detected_bins['m1']
d_mass2 = detected_bins['m2']
d_mass_ratio = d_mass2/d_mass1


f,(ax1,ax2,ax3) = plt.subplots(1,3, figsize = (10,6))
ax1.hist(mass_ratio, bins = 50, range = (0,2), color = '#99badd')
ax2.hist(i_mass_ratio, bins = 50, range = (0,2), color = '#99badd')
ax3.hist(d_mass_ratio, bins = 50, range = (0,2), color = '#99badd')
ax1.set_xlabel('$M_2$/$M_1$ (All Binaries)', fontsize = 12)
ax2.set_xlabel('$M_2$/$M_1$ (Detected Binaries)', fontsize = 12)
ax3.set_xlabel('$M_2$/$M_1$ (Identified Binaries)', fontsize = 12)
ax1.set_ylabel('Number of Binaries, N', fontsize = 16)
f.savefig('mass_dist.png')

# %%
# Aaron's pseudo-code

# mydict= {‘RA’:[], ‘Dec’:[], ‘frac’:[]}
# for file in allFiles:
#         dat1 = #read in the first line
#         dat2 = #read in the rest        
#         mydict[‘RA’].append(dat1[‘RA’])
#         #same for ‘Dec’
#         f = #calculate the fraction detected in dat2
#         mydict[‘frac’].append(f)

#plot mydict keys ‘RA', ‘Dec' in mollweide, and color by key ‘frac’

# %%
import glob
path ='/Users/andrewbowen/BO_EB-LSST/code/OpSim' # use your path
allFiles = glob.glob(path + "/*.csv")

# %%
IDdict = {'RA':np.array([]), 'Dec':np.array([]), 'frac':np.array([])}

for file in allFiles:
    dat1 = pd.read_csv(file, sep = ',', header=0, nrows = 1)
    dat2 = pd.read_csv(file, sep = ',', header=2)
#     appending RA/Dec to dictionary
    if dat2['p'].values[0] != -1:
        IDdict['RA'] = np.append(IDdict['RA'],dat1['OpSimRA'])
        IDdict['Dec'] = np.append(IDdict['Dec'], dat1['OpSimDec'])

    #     Criteria for period recovery
        PeriodIn = dat2['p']
        PeriodOut = dat2['LSM_PERIOD']
        pdiff = abs(PeriodIn.values - PeriodOut.values)/PeriodIn.values
        f = 0

        recovered_p = dat2['LSM_PERIOD'].loc[pdiff<0.1]
        all_p = dat2['LSM_PERIOD']
    #     Putting recovered period into 'frac' lists
        f = recovered_p.shape[0]/all_p.shape[0]

    
        IDdict['frac'] = np.append(IDdict['frac'],f)

# IDdict

# %%
# print(IDdict)
f, ax = plt.subplots()
ax.scatter(IDdict['RA'],IDdict['Dec'],cmap = 'viridis', c = IDdict['frac'],vmin=0, vmax=0.002)

# %%
RA = IDdict['RA']
Dec = IDdict['Dec']
Coords = SkyCoord(RA,Dec,unit=(u.degree, u.degree),frame='icrs')
# print(Coords)

# %%
# Plotting time baby
plt.figure()
plt.subplot( projection = 'mollweide' )
plt.grid(True)

# plt.scatter((IDdict['RA']*np.pi/180),(IDdict['Dec']*np.pi/180),\
#             cmap = 'Blues', c = IDdict['frac']*100, vmin=0, vmax=0.2)


plt.scatter(Coords.ra.wrap_at(180.*u.degree).radian,Coords.dec.radian, s = 20,\
           cmap = 'Blues', c = IDdict['frac']*100, vmin = 0, vmax = 0.2)

plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

clb = plt.colorbar()
clb.set_label(r'% Periods Recovered', fontsize = 18, rotation = 270, labelpad = 20)
plt.xlabel(r'$\alpha$', fontsize = 16)
plt.ylabel(r'$\delta$', fontsize = 16) 
plt.savefig('mollweide_percent_rec.pdf')

# %%
# Defining variables to be plotted

# Period
p = frame2['p']
d_p = detected_bins['p']
i_p = P_Recover['p']


# Eccentricity
ecc = frame2['e']
d_ecc = detected_bins['e']
i_ecc = P_Recover['e']

# Radius
radius1 = frame2['r1']
radius2 = frame2['r2']
radius_ratio = radius2/radius1
d_radius = detected_bins['r2']/detected_bins['r1']
i_radius = P_Recover['r2']/P_Recover['r1']

# Inclination
d_inc = detected_bins['i']
i_inc = P_Recover['i']
inc = frame2['i']

# %%
# Big Grid Plot

# Items to plot for all 3: Period, ecc, mass ratio, radius ratio, inclination
# Separate column for cumulative plots


f, axarr = plt.subplots(5,4, figsize = (12,12))
f.subplots_adjust(wspace=0.3, hspace = 0.3)
# column titles
axarr[0,0].set_title('All Binaries')
axarr[0,1].set_title('Observable EBs')
axarr[0,2].set_title('Recoverable EBs')
axarr[0,3].set_title('Cumulative Plots')



# Period
axarr[0,0].hist(p, bins = 50, range = (0,10), color = '#99badd')
axarr[0,1].hist(d_p, bins = 50, range = (0,10), color = '#99badd')
axarr[0,2].hist(i_p, bins = 50, range = (0,10), color = '#99badd')
axarr[0,0].set_ylabel('Period', fontsize = 18)
axarr[0,3].hist(p, bins = 50, range = (0,10), color = '#767676',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[0,3].hist(d_p, bins = 50, range = (0,10), color = '#13294B',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[0,3].hist(i_p, bins = 50, range = (0,10), color = '#99badd', normed = True,\
                histtype = 'step', fill = False,cumulative = True)

# Mass Ratio
axarr[1,0].hist(mass_ratio, bins = 50, range = (0,2), color = '#13294B')
axarr[1,1].hist(d_mass_ratio, bins = 50, range = (0,2), color = '#13294B')
axarr[1,2].hist(i_mass_ratio, bins = 50, range = (0,2), color = '#13294B')
axarr[1,0].set_ylabel('$M_2$/$M_1$', fontsize = 18)

axarr[1,3].hist(mass_ratio, bins = 50, range = (0,2), color = '#767676',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[1,3].hist(d_mass_ratio, bins = 50, range = (0,2), color = '#13294B',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[1,3].hist(i_mass_ratio, bins = 50, range = (0,2), color = '#99badd', normed = True,\
                histtype = 'step', fill = False,cumulative = True)

# Eccentricity
axarr[2,0].hist(ecc, bins = 50, range = (0,1), color = '#99badd')
axarr[2,1].hist(d_ecc, bins = 50, range = (0,1), color = '#99badd')
axarr[2,2].hist(id_ecc, bins = 50, range = (0,1), color = '#99badd')
axarr[2,0].set_ylabel('Eccentricity', fontsize = 18)
axarr[2,3].hist(ecc, bins = 50, range = (0,1), color = '#767676',normed = True,\
             histtype = 'step', fill = False,cumulative = True)
axarr[2,3].hist(d_ecc, bins = 50, range = (0,1), color = '#13294B',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[2,3].hist(i_ecc, bins = 50, range = (0,1), color = '#99badd', normed = True,\
                histtype = 'step', fill = False,cumulative = True)

# Radius Ratio
axarr[3,0].hist(radius_ratio, bins = 50, range = (0,1), color = '#13294B')
axarr[3,1].hist(d_radius, bins = 50, range = (0,1), color = '#13294B')
axarr[3,2].hist(i_radius, bins = 50, range = (0,1), color = '#13294B')
axarr[3,0].set_ylabel('$R_2$/$R_1$', fontsize = 18)
axarr[3,3].hist(radius_ratio, bins = 50, range = (0,1), color = '#767676',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,3].hist(d_radius, bins = 50, range = (0,1), color = '#13294B',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,3].hist(i_radius, bins = 50, range = (0,1), color = '#99badd', normed = True,\
                histtype = 'step', fill = False,cumulative = True)

#Inclination 
axarr[4,0].hist(inc, bins = 50, range = (0,90), color = '#99badd')
axarr[4,1].hist(d_inc, bins = 50, range = (0,90), color = '#99badd')
axarr[4,2].hist(i_inc, bins = 50, range = (0,90), color = '#99badd')
axarr[4,0].set_ylabel('Inclination', fontsize = 18)
axarr[4,3].hist(inc, bins = 500, range = (0,90), color = '#767676',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[4,3].hist(d_inc, bins = 500, range = (0,90), color = '#13294B',normed = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[4,3].hist(i_inc, bins = 500, range = (0,90), color = '#99badd', normed = True,\
                histtype = 'step', fill = False,cumulative = True)

# f.savefig('Poster_grid_plot.pdf')

# %%
# Reformatted baby
f, axarr = plt.subplots(4,5, figsize = (18,12), sharex = 'col')
f.subplots_adjust(wspace=0.3, hspace = 0)
# column titles
axarr[0,0].set_title('Period', fontsize = 24)
axarr[0,1].set_title('$M_1$/$M_2$', fontsize = 24)
axarr[0,2].set_title('Eccentricity', fontsize = 24)
axarr[0,3].set_title('$R_1$/$R_2$', fontsize = 24)
axarr[0,4].set_title('Inclination', fontsize = 24)
axarr[0,0].set_ylabel('All Binaries', fontsize = 18)
axarr[1,0].set_ylabel('Observable EBs', fontsize = 18)
axarr[2,0].set_ylabel('Recoverable EBs', fontsize = 18)
axarr[3,0].set_ylabel('Cumulative', fontsize = 18)


# Period
axarr[0,0].hist(p, bins = 50, range = (0,10), color = '#13294B')
axarr[1,0].hist(d_p, bins = 50, range = (0,10), color = '#356897')
axarr[2,0].hist(i_p, bins = 50, range = (0,10), color = '#99badd')
# axarr[0,0].set_xlabel('Period', fontsize = 18)
axarr[3,0].hist(p, bins = 1000, range = (0,10), color = '#13294B',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,0].hist(d_p, bins = 1000, range = (0,10), color = '#356897',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,0].hist(i_p, bins = 1000, range = (0,10), color = '#99badd', density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,0].set_xlabel('Days')

# Mass Ratio
axarr[0,1].hist(mass_ratio, bins = 50, range = (0,2), color = '#13294B')
axarr[1,1].hist(d_mass_ratio, bins = 50, range = (0,2), color = '#356897')
axarr[2,1].hist(i_mass_ratio, bins = 50, range = (0,2), color = '#99badd')
# axarr[3,1].set_xlabel('$M_2$/$M_1$', fontsize = 18)

axarr[3,1].hist(mass_ratio, bins = 1000, range = (0,2), color = '#13294B',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,1].hist(d_mass_ratio, bins = 1000, range = (0,2), color = '#356897',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,1].hist(i_mass_ratio, bins = 1000, range = (0,2), color = '#99badd', density = True,\
                histtype = 'step', fill = False,cumulative = True)


# Eccentricity
axarr[0,2].hist(ecc, bins = 50, range = (0,1), color = '#13294B')
axarr[1,2].hist(d_ecc, bins = 50, range = (0,1), color = '#356897')
axarr[2,2].hist(id_ecc, bins = 50, range = (0,1), color = '#99badd')
# axarr[2,2].set_xlabel('Eccentricity', fontsize = 18)
axarr[3,2].hist(ecc, bins = 1000, range = (0,1), color = '#13294B',density = True,\
             histtype = 'step', fill = False,cumulative = True)
axarr[3,2].hist(d_ecc, bins = 1000, range = (0,1), color = '#356897',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,2].hist(i_ecc, bins = 1000, range = (0,1), color = '#99badd', density = True,\
                histtype = 'step', fill = False,cumulative = True)

# Radius Ratio
axarr[0,3].hist(radius_ratio, bins = 50, range = (0,1), color = '#13294B')
axarr[1,3].hist(d_radius, bins = 50, range = (0,1), color = '#356897')
axarr[2,3].hist(i_radius, bins = 50, range = (0,1), color = '#99badd')
# axarr[,0].set_xlabel('$R_2$/$R_1$', fontsize = 18)
axarr[3,3].hist(radius_ratio, bins = 1000, range = (0,1), color = '#13294B',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,3].hist(d_radius, bins = 1000, range = (0,1), color = '#356897',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,3].hist(i_radius, bins = 1000, range = (0,1), color = '#99badd', density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,3].set_xlabel('Degrees')

#Inclination 
axarr[0,4].hist(inc, bins = 50, range = (0,90), color = '#13294B')
axarr[1,4].hist(d_inc, bins = 50, range = (0,90), color = '#356897')
axarr[2,4].hist(i_inc, bins = 50, range = (0,90), color = '#99badd')
# axarr[4,0].set_ylabel('Inclination', fontsize = 18)
axarr[3,4].hist(inc, bins = 1000, range = (0,90), color = '#13294B',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,4].hist(d_inc, bins = 1000, range = (0,90), color = '#356897',density = True,\
                histtype = 'step', fill = False,cumulative = True)
axarr[3,4].hist(i_inc, bins = 1000, range = (0,90), color = '#99badd', density = True,\
                histtype = 'step', fill = False,cumulative = True)

f.savefig('Poster_grid_plot.pdf')
